# %%
import matplotlib.pyplot as plt
import pydicom
from matplotlib.widgets import Slider, Button #slider implementeren
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
filename_1 = "C:\\Users\\Werk\\OneDrive - UGent\\Burgie 4\\Sem 2\\VOP\\Coding\\microCT data X-Cube\\584_l0r0\\20211021150245_CT_ISRA_0.dcm"
dataset_1 = pydicom.dcmread(filename_1)

filename_2 = "C:\\Users\\Werk\OneDrive - UGent\\Burgie 4\\Sem 2\\VOP\\Coding\\microCT data X-Cube\\584_l0r0\\20211022112307_CT_ISRA_0.dcm"
dataset_2 = pydicom.dcmread(filename_2)

# %%
f, ax = plt.subplots(1,2,figsize = (10,10))
ax[0].imshow(dataset_2.pixel_array[80], cmap=plt.cm.bone)
ax[1].imshow(dataset_1.pixel_array[80], cmap=plt.cm.bone)
plt.show()
print(dataset_1.pixel_array.shape)
print(np.max(dataset_1.pixel_array[80]))
plt.imshow(dataset_1.pixel_array[80]/np.max(dataset_1.pixel_array[0]), cmap=plt.cm.bone)
plt.show()
# Out:
# (188, 200, 200)
# 5604

# %%
def normalize(x):
    return x/np.max(x)

# %%
num_epochs = 4
batch_size = 4
learning_rate = 0.001

# %%
class ConvNet(nn.Module):
    def __init__(self):
        pass
    def forward(self,x):
        pass

model = ConvNet().to(device)

cirterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = learning_rate)

n_total_steps = len(train_loader)
for epoch in range(num_epochs):
    outputs = model(images)
    loss = cirterion(outputs, labels)

    #backward and optim
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4300\1048590546.py in <module>
#       5         pass
#       6
# ----> 7 model = ConvNet().to(device)
#       8
#       9 cirterion = nn.CrossEntropyLoss()
#
# c:\Users\Werk\OneDrive - UGent\Burgie 4\Sem 2\VOP\Coding\VOPENV\lib\site-packages\torch\nn\modules\module.py in to(self, *args, **kwargs)
#     897             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#     898
# --> 899         return self._apply(convert)
#     900
#     901     def register_backward_hook(
#
# c:\Users\Werk\OneDrive - UGent\Burgie 4\Sem 2\VOP\Coding\VOPENV\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     567
#     568     def _apply(self, fn):
# --> 569         for module in self.children():
#     570             module._apply(fn)
#     571
#
# ...
